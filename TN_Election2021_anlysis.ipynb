# %% [markdown]
# <a href="https://colab.research.google.com/github/dssreedhar/PYTHON-PROJECTS/blob/main/TN_Election2021_anlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/all_candidate.csv')
df.head()
# Out:
#    O.S.N.         Candidate                             Party  EVM Votes  \
# 0       1  GOVINDARAJAN T.J         Dravida Munnetra Kazhagam     125001
# 1       2        DILLIY K.M  Desiya Murpokku Dravida Kazhagam       2553
# 2       3         NAGARAJ S               Bahujan Samaj Party       1031
# 3       4              USHA               Naam Tamilar Katchi      11643
# 4       5         GOWTHAM J    Anaithu Makkal Arasiyal Katchi        254
#
#    Postal Votes  Total Votes  % of Votes  AC_NO  Position Party Code
# 0          1451       126452       56.94      1         1        DMK
# 1            23         2576        1.16      1         4       DMDK
# 2             7         1038        0.47      1         6        BSP
# 3            58        11701        5.27      1         3        NTK
# 4             0          254        0.11      1        12       AMAK

# %%
df = pd.read_csv('/content/winners.csv')
df.head()
# Out:
#    O.S.N.            Candidate                      Party  EVM Votes  \
# 0       1     GOVINDARAJAN T.J  Dravida Munnetra Kazhagam     125001
# 1       1  DURAI. CHANDRASEKAR   Indian National Congress      93669
# 2       3           S.Chandran  Dravida Munnetra Kazhagam     118005
# 3       1     RAAJENDRAN, V.G.  Dravida Munnetra Kazhagam     106316
# 4       1       Krishnaswamy A  Dravida Munnetra Kazhagam     148383
#
#    Postal Votes  Total Votes  % of Votes  AC_NO  Position Party Code
# 0          1451       126452       56.94      1         1        DMK
# 1           859        94528       44.94      2         1        INC
# 2          2309       120314       51.72      3         1        DMK
# 3          1393       107709       50.27      4         1        DMK
# 4          1195       149578       56.72      5         1        DMK

# %%
cat_columns = df.select_dtypes(include = "O")
num_columns = df.drop(columns = ["O.S.N."]).select_dtypes(include = "number")
print("Categarical Columns", list(cat_columns))
print("Numerical Columns", list(num_columns))
# Out:
# Categarical Columns ['Candidate', 'Party', 'Party Code']
# Numerical Columns ['EVM Votes', 'Postal Votes', 'Total Votes', '% of Votes', 'AC_NO', 'Position']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
